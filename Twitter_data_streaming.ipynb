# %% [markdown]
# # importing libraries

# %%
import findspark

# %%
findspark.init('/home/tam/spark-3.0.0-preview-bin-hadoop2.7/')

# %%
from pyspark import SparkContext

# %%
from pyspark.streaming import StreamingContext

# %%
# two working threads
sc = SparkContext('local[2]','NetworkWordCount')

# %%
# 1sec
ssc = StreamingContext(sc, 1)

# %%
lines = ssc.socketTextStream('localhost',9999)

# %%
words = lines.flatMap(lambda line: line.split(' '))

# %%
pairs = words.map(lambda word:(word, 1))

# %%
word_counts = pairs.reduceByKey(lambda num1, num2: num1+num2)

# %%
word_counts.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2019-12-11 08:32:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:16
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:21
# -------------------------------------------
# ('hello', 1)
#
# -------------------------------------------
# Time: 2019-12-11 08:32:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:24
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:25
# -------------------------------------------
# ('hello', 2)
#
# -------------------------------------------
# Time: 2019-12-11 08:32:26
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:27
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:28
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:29
# -------------------------------------------
# ('am', 1)
# ('I', 1)
# ('Tamilarasan', 1)
#
# -------------------------------------------
# Time: 2019-12-11 08:32:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:31
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:32
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:33
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-12-11 08:32:39
# -------------------------------------------
